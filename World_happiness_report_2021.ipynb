# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size']=15
plt.rcParams['figure.figsize']=(10,7)
plt.rcParams['figure.facecolor']='FFE5B4'

# %%
data=pd.read_csv(r'C:\Users\User\Desktop\data_hub\world-happiness-report-2021.csv')

# %%
data.head(3)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
# ...

# %%
data.shape
# Out:
# (149, 20)

# %%
data.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
data.describe().transpose()
# Out:
#                                             count       mean           std  \
# Ladder score                                149.0   5.532839  1.073924e+00
# Standard error of ladder score              149.0   0.058752  2.200120e-02
# upperwhisker                                149.0   5.648007  1.054330e+00
# lowerwhisker                                149.0   5.417631  1.094879e+00
# Logged GDP per capita                       149.0   9.432208  1.158601e+00
# Social support                              149.0   0.814745  1.148890e-01
# Healthy life expectancy                     149.0  64.992799  6.762043e+00
# Freedom to make life choices                149.0   0.791597  1.133318e-01
# Generosity                                  149.0  -0.015134  1.506567e-01
# Perceptions of corruption                   149.0   0.727450  1.792263e-01
# Ladder score in Dystopia                    149.0   2.430000  5.347044e-15
# ...

# %%
data.head(3)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
# ...

# %%
data=data.rename(columns={'Ladder score':'Happiness Score'})
#df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})

# %%
data.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Happiness Score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
data_selected_columns=['Country name', 'Regional indicator', 'Happiness Score','Logged GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices', 'Generosity','Perceptions of corruption', ]

# %%
data=data[data_selected_columns].copy()

# %%
data.shape
# Out:
# (149, 9)

# %%
happy_data=data.rename(columns={'Country name':'Country_name','Regional indicator':'Regional_indicator','Happiness Score':'Happiness_Score','Logged GDP per capita':'Logged_GDP_per_capita','Social support':'Social_support','Healthy life expectancy':'Healthy_life_expectancy','Freedom to make life choices':'Freedom_to_make_life_choices','Perceptions of corruption':'Perceptions_of_corruption'})

# %%
happy_data.head()
# Out:
#   Country_name Regional_indicator  Happiness_Score  Logged_GDP_per_capita  \
# 0      Finland     Western Europe            7.842                 10.775
# 1      Denmark     Western Europe            7.620                 10.933
# 2  Switzerland     Western Europe            7.571                 11.117
# 3      Iceland     Western Europe            7.554                 10.878
# 4  Netherlands     Western Europe            7.464                 10.932
#
#    Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions_of_corruption
# ...

# %%
happy_data.isnull().sum()
# Out:
# Country_name                    0
# Regional_indicator              0
# Happiness_Score                 0
# Logged_GDP_per_capita           0
# Social_support                  0
# Healthy_life_expectancy         0
# Freedom_to_make_life_choices    0
# Generosity                      0
# Perceptions_of_corruption       0
# dtype: int64

# %%
plt.figure(figsize=(15,7))
plt.title('Plot between Happiness Score and GDP')
sns.scatterplot(x=happy_data['Happiness_Score'],y=happy_data['Logged_GDP_per_capita'],hue=happy_data['Regional_indicator'],s=200)
plt.legend(loc='upper left',fontsize='10')
plt.xlabel('Happiness Score')
plt.ylabel('GDP per capita')
plt.show()

# %%
gdp_region=happy_data.groupby('Regional_indicator')['Logged_GDP_per_capita'].sum()

# %%
gdp_region
# Out:
# Regional_indicator
# Central and Eastern Europe            171.854
# Commonwealth of Independent States    112.822
# East Asia                              62.206
# Latin America and Caribbean           187.400
# Middle East and North Africa          164.324
# North America and ANZ                  43.238
# South Asia                             60.778
# Southeast Asia                         84.793
# Sub-Saharan Africa                    290.707
# Western Europe                        227.277
# Name: Logged_GDP_per_capita, dtype: float64

# %%
gdp_region.plot.pie(autopct='%1.1f%%')
plt.title('GDP per region')
plt.ylabel('')
plt.show()

# %%
total_country=happy_data.groupby('Regional_indicator')['Country_name'].count()

# %%
total_country
# Out:
# Regional_indicator
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# East Asia                              6
# Latin America and Caribbean           20
# Middle East and North Africa          17
# North America and ANZ                  4
# South Asia                             7
# Southeast Asia                         9
# Sub-Saharan Africa                    36
# Western Europe                        21
# Name: Country_name, dtype: int64

# %%
happy_data.columns
# Out:
# Index(['Country_name', 'Regional_indicator', 'Happiness_Score',
#        'Logged_GDP_per_capita', 'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
happy_data.head(3)
# Out:
#   Country_name Regional_indicator  Happiness_Score  Logged_GDP_per_capita  \
# 0      Finland     Western Europe            7.842                 10.775
# 1      Denmark     Western Europe            7.620                 10.933
# 2  Switzerland     Western Europe            7.571                 11.117
#
#    Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
#
#    Generosity  Perceptions_of_corruption
# 0      -0.098                      0.186
# 1       0.030                      0.179
# 2       0.025                      0.292

# %%
happy_data.columns
# Out:
# Index(['Country_name', 'Regional_indicator', 'Happiness_Score',
#        'Logged_GDP_per_capita', 'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
df=['Happiness_Score','Logged_GDP_per_capita', 'Social_support', 'Healthy_life_expectancy','Freedom_to_make_life_choices', 'Generosity','Perceptions_of_corruption']

# %%
data=happy_data[df].copy()

# %%
data.head(3)
# Out:
#    Happiness_Score  Logged_GDP_per_capita  Social_support  \
# 0            7.842                 10.775           0.954
# 1            7.620                 10.933           0.954
# 2            7.571                 11.117           0.942
#
#    Healthy_life_expectancy  Freedom_to_make_life_choices  Generosity  \
# 0                     72.0                         0.949      -0.098
# 1                     72.7                         0.946       0.030
# 2                     74.4                         0.919       0.025
#
#    Perceptions_of_corruption
# 0                      0.186
# 1                      0.179
# 2                      0.292

# %%
corr_matrix=data.corr()

# %%
corr_matrix
# Out:
#                               Happiness_Score  Logged_GDP_per_capita  \
# Happiness_Score                      1.000000               0.789760
# Logged_GDP_per_capita                0.789760               1.000000
# Social_support                       0.756888               0.785299
# Healthy_life_expectancy              0.768099               0.859461
# Freedom_to_make_life_choices         0.607753               0.432323
# Generosity                          -0.017799              -0.199286
# Perceptions_of_corruption           -0.421140              -0.342337
#
#                               Social_support  Healthy_life_expectancy  \
# Happiness_Score                     0.756888                 0.768099
# Logged_GDP_per_capita               0.785299                 0.859461
# Social_support                      1.000000                 0.723256
# Healthy_life_expectancy             0.723256                 1.000000
# ...

# %%
happy_data.columns
# Out:
# Index(['Country_name', 'Regional_indicator', 'Happiness_Score',
#        'Logged_GDP_per_capita', 'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
corruption=happy_data.groupby('Regional_indicator')[['Perceptions_of_corruption']].mean()

# %%
corruption
# Out:
#                                     Perceptions_of_corruption
# Regional_indicator
# Central and Eastern Europe                           0.850529
# Commonwealth of Independent States                   0.725083
# East Asia                                            0.683333
# Latin America and Caribbean                          0.792600
# Middle East and North Africa                         0.762235
# North America and ANZ                                0.449250
# South Asia                                           0.797429
# Southeast Asia                                       0.709111
# Sub-Saharan Africa                                   0.765944
# Western Europe                                       0.523095

# %%
plt.rcParams['figure.figsize']=(12,8)
plt.title('Perceptions of corruptions in various regions')
plt.xlabel('Regions',fontsize=15)
plt.ylabel('Corruption Index',fontsize=15)
plt.xticks(rotation=30,ha='right')
plt.bar(corruption.index,corruption.Perceptions_of_corruption)
plt.show()

# %%
top_10=happy_data.head(10)
bottom_10=happy_data.tail(10)

# %%
top_10
# Out:
#   Country_name     Regional_indicator  Happiness_Score  Logged_GDP_per_capita  \
# 0      Finland         Western Europe            7.842                 10.775
# 1      Denmark         Western Europe            7.620                 10.933
# 2  Switzerland         Western Europe            7.571                 11.117
# 3      Iceland         Western Europe            7.554                 10.878
# 4  Netherlands         Western Europe            7.464                 10.932
# 5       Norway         Western Europe            7.392                 11.053
# 6       Sweden         Western Europe            7.363                 10.867
# 7   Luxembourg         Western Europe            7.324                 11.647
# 8  New Zealand  North America and ANZ            7.277                 10.643
# 9      Austria         Western Europe            7.268                 10.906
#
#    Social_support  Healthy_life_expectancy  Freedom_to_make_life_choices  \
# ...

# %%
bottom_10
# Out:
#     Country_name            Regional_indicator  Happiness_Score  \
# 139      Burundi            Sub-Saharan Africa            3.775
# 140        Yemen  Middle East and North Africa            3.658
# 141     Tanzania            Sub-Saharan Africa            3.623
# 142        Haiti   Latin America and Caribbean            3.615
# 143       Malawi            Sub-Saharan Africa            3.600
# 144      Lesotho            Sub-Saharan Africa            3.512
# 145     Botswana            Sub-Saharan Africa            3.467
# 146       Rwanda            Sub-Saharan Africa            3.415
# 147     Zimbabwe            Sub-Saharan Africa            3.145
# 148  Afghanistan                    South Asia            2.523
#
#      Logged_GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 139                  6.635           0.490                   53.400
# 140                  7.578           0.832                   57.122
# ...

# %%
fig, axes=plt.subplots(1,2,figsize=(16,6))
plt.tight_layout(pad=2)
xlabels=top_10.Country_name
axes[0].set_title('Top 10 Happiest countries life expectancy')
axes[0].set_xticklabels(xlabels, rotation=45,ha='right')
sns.barplot(x=top_10.Country_name,y=top_10.Healthy_life_expectancy,ax=axes[0])
axes[0].set_xlabel('Country Name')
axes[0].set_ylabel('Life expectancy')

xlabels=bottom_10.Country_name
axes[1].set_title('Bottom 10 least Happiest countries life expectancy')
axes[1].set_xticklabels(xlabels, rotation=45,ha='right')
sns.barplot(x=bottom_10.Country_name,y=bottom_10.Healthy_life_expectancy,ax=axes[1])
axes[1].set_xlabel('Country Name')
axes[1].set_ylabel('Life expectancy')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8496\4236286298.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(xlabels, rotation=45,ha='right')
# C:\Users\User\AppData\Local\Temp\ipykernel_8496\4236286298.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(xlabels, rotation=45,ha='right')

# %%
happy_data.columns
# Out:
# Index(['Country_name', 'Regional_indicator', 'Happiness_Score',
#        'Logged_GDP_per_capita', 'Social_support', 'Healthy_life_expectancy',
#        'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize']=(12,8)
sns.scatterplot(x=happy_data.Freedom_to_make_life_choices,y=happy_data.Happiness_Score,hue=happy_data.Regional_indicator,s=200)
plt.legend(loc='upper left',fontsize=12)
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness Scores')
plt.show()

# %%
country=happy_data.sort_values(by='Perceptions_of_corruption').head(10)

# %%
country
# Out:
#     Country_name     Regional_indicator  Happiness_Score  \
# 31     Singapore         Southeast Asia            6.377
# 146       Rwanda     Sub-Saharan Africa            3.415
# 1        Denmark         Western Europe            7.620
# 0        Finland         Western Europe            7.842
# 6         Sweden         Western Europe            7.363
# 8    New Zealand  North America and ANZ            7.277
# 5         Norway         Western Europe            7.392
# 2    Switzerland         Western Europe            7.571
# 4    Netherlands         Western Europe            7.464
# 14       Ireland         Western Europe            7.085
#
#      Logged_GDP_per_capita  Social_support  Healthy_life_expectancy  \
# 31                  11.488           0.915                   76.953
# 146                  7.676           0.552                   61.400
# 1                   10.933           0.954                   72.700
# ...

# %%
plt.rcParams['figure.figsize']=(10,6)
plt.bar(country.Country_name,country.Perceptions_of_corruption)
plt.title('Countries with most Perception of corruptions')
plt.xlabel('Country')
plt.ylabel('Corruption Index')
plt.xticks(rotation=30,ha='right')
plt.show()

# %%
country_lowest=happy_data.sort_values(by='Perceptions_of_corruption').tail(10)
plt.rcParams['figure.figsize']=(10,6)
plt.bar(country_lowest.Country_name,country_lowest.Perceptions_of_corruption)
plt.title('Countries with most lowest Perception of corruptions')
plt.xlabel('Country')
plt.ylabel('Corruption Index')
plt.xticks(rotation=30,ha='right')
plt.show()

# %%
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=happy_data.Happiness_Score,y=happy_data.Perceptions_of_corruption,hue=happy_data.Regional_indicator,s=200)
plt.title('Countries with most lowest Perception of corruptions')
plt.xlabel('Happiness Score')
plt.ylabel('Corruption')
plt.legend(loc='lower left',fontsize='14')
plt.show()
